# %% [markdown]
# # Proyek Akhir: Student Dropout Prediction - Perusahaan Edutech
#
# - **Nama**: [Andy Yulianto]
# - **Email**: [rinovannet@gmail.com]
# - **Id Dicoding**: [andyid]
# - **Dataset**: data.csv (4.424 baris, 37 kolom)
# - **Sumber**: UCI Machine Learning Repository
# - **Klasifikasi**: Binary (Dropout vs Graduate) — data Enrolled digunakan untuk inferensi

# %% [markdown]
# ---
# ## Ringkasan Proyek
#
# ### Permasalahan
# Perusahaan Edutech menghadapi masalah **tingginya angka dropout** mahasiswa.
#
# ### Tujuan
# 1. Menganalisis faktor penyebab dropout
# 2. Membangun model prediksi dropout (binary: Dropout vs Graduate)
# 3. Menyediakan dashboard monitoring
# 4. Memberikan rekomendasi action items
#
# ### Pendekatan Klasifikasi
# - **Training data**: Hanya mahasiswa dengan status **Dropout** dan **Graduate**
# - **Data Enrolled**: Digunakan untuk **inferensi/prediksi** (opsional) — memprediksi kemungkinan status akhir di masa depan
# - **Alasan**: Enrolled adalah status sementara, bukan outcome akhir yang valid untuk pelatihan model
#
# ### Solusi Machine Learning
# - **Logistic Regression**: Baseline model
# - **Random Forest**: Model utama
# - **Alasan Random Forest**: Akurasi lebih tinggi, ada feature importance, robust terhadap outlier
#
# ### Tools yang Digunakan
# - **Jupyter Notebook**: Analisis & training model
# - **Streamlit**: Prototype prediksi (UI)
# - **Metabase**: Dashboard monitoring
# - **Docker**: PostgreSQL & Metabase

# %% [markdown]
# ---
# ## Persiapan

# %% [markdown]
# ### Install Dependencies
#
# Jalankan cell ini jika package belum terinstall:

# %%
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])

packages = [
    'pandas', 'numpy', 'matplotlib', 'seaborn',
    'scikit-learn==1.2.2', 'joblib', 'sqlalchemy', 'psycopg2-binary'
]

for pkg in packages:
    try:
        __import__(pkg.replace('-', '_').split('==')[0])
        print(f"✅ {pkg} sudah terinstall")
    except ImportError:
        print(f"Installing {pkg}...")
        install(pkg)
        print(f"  ✅ {pkg} installed")

print("\n✅ Semua dependencies siap!")
# Out:
# ✅ pandas sudah terinstall
# ✅ numpy sudah terinstall
# ✅ matplotlib sudah terinstall
# ✅ seaborn sudah terinstall
# Installing scikit-learn==1.2.2...
#   ✅ scikit-learn==1.2.2 installed
# ✅ joblib sudah terinstall
# ✅ sqlalchemy sudah terinstall
# Installing psycopg2-binary...
#   ✅ psycopg2-binary installed
#
# ✅ Semua dependencies siap!

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sqlalchemy import create_engine, text
import joblib
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
print("✅ Semua library berhasil diimport!")
# Out:
# ✅ Semua library berhasil diimport!

# %% [markdown]
# ---
# ## Data Understanding

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('data/data.csv', sep=';')
print(f"Dataset shape: {df.shape}")
print(f"Jumlah baris: {df.shape[0]}")
print(f"Jumlah kolom: {df.shape[1]}")
print(f"\nKolom: {list(df.columns)}")
df.head()
# Out:
# Dataset shape: (4424, 37)
# Jumlah baris: 4424
# Jumlah kolom: 37
#
# Kolom: ['Marital_status', 'Application_mode', 'Application_order', 'Course', 'Daytime_evening_attendance', 'Previous_qualification', 'Previous_qualification_grade', 'Nacionality', 'Mothers_qualification', 'Fathers_qualification', 'Mothers_occupation', 'Fathers_occupation', 'Admission_grade', 'Displaced', 'Educational_special_needs', 'Debtor', 'Tuition_fees_up_to_date', 'Gender', 'Scholarship_holder', 'Age_at_enrollment', 'International', 'Curricular_units_1st_sem_credited', 'Curricular_units_1st_sem_enrolled', 'Curricular_units_1st_sem_evaluations', 'Curricular_units_1st_sem_approved', 'Curricular_units_1st_sem_grade', 'Curricular_units_1st_sem_without_evaluations', 'Curricular_units_2nd_sem_credited', 'Curricular_units_2nd_sem_enrolled', 'Curricular_units_2nd_sem_evaluations', 'Curricular_units_2nd_sem_approved', 'Curricular_units_2nd_sem_grade', 'Curricular_units_2nd_sem_without_evaluations', 'Unemployment_rate', 'Inflation_rate', 'GDP', 'Status']
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# 2                         122.0            1                     37
# 3                         122.0            1                     38
# 4                         100.0            1                     37
#
#    Fathers_qualification  ...  Curricular_units_2nd_sem_credited  \
# 0                     12  ...                                  0
# 1                      3  ...                                  0
# 2                     37  ...                                  0
# 3                     37  ...                                  0
# 4                     38  ...                                  0
#
#    Curricular_units_2nd_sem_enrolled  Curricular_units_2nd_sem_evaluations  \
# 0                                  0                                     0
# 1                                  6                                     6
# 2                                  6                                     0
# 3                                  6                                    10
# 4                                  6                                     6
#
#    Curricular_units_2nd_sem_approved  Curricular_units_2nd_sem_grade  \
# 0                                  0                        0.000000
# 1                                  6                       13.666667
# 2                                  0                        0.000000
# 3                                  5                       12.400000
# 4                                  6                       13.000000
#
#    Curricular_units_2nd_sem_without_evaluations  Unemployment_rate  \
# 0                                             0               10.8
# 1                                             0               13.9
# 2                                             0               10.8
# 3                                             0                9.4
# 4                                             0               13.9
#
#    Inflation_rate   GDP    Status
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Info Dataset

# %%
print("=" * 60)
print("INFORMASI DATASET")
print("=" * 60)
print(f"Jumlah baris: {df.shape[0]}")
print(f"Jumlah kolom: {df.shape[1]}")
print(f"\nMissing values: {df.isnull().sum().sum()}")
print(f"\nTipe data:")
print(df.dtypes.value_counts())
# Out:
# ============================================================
# INFORMASI DATASET
# ============================================================
# Jumlah baris: 4424
# Jumlah kolom: 37
#
# Missing values: 0
#
# Tipe data:
# int64      29
# float64     7
# object      1
# Name: count, dtype: int64

# %% [markdown]
# ### Statistik Deskriptif

# %%
df.describe()
# Out:
#        Marital_status  Application_mode  Application_order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime_evening_attendance  Previous_qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# 25%                      1.000000                1.000000
# 50%                      1.000000                1.000000
# 75%                      1.000000                1.000000
# max                      1.000000               43.000000
#
#        Previous_qualification_grade  Nacionality  Mothers_qualification  \
# count                   4424.000000  4424.000000            4424.000000
# mean                     132.613314     1.873192              19.561935
# std                       13.188332     6.914514              15.603186
# min                       95.000000     1.000000               1.000000
# 25%                      125.000000     1.000000               2.000000
# 50%                      133.100000     1.000000              19.000000
# 75%                      140.000000     1.000000              37.000000
# max                      190.000000   109.000000              44.000000
#
#        Fathers_qualification  ...  \
# count            4424.000000  ...
# mean               22.275316  ...
# std                15.343108  ...
# min                 1.000000  ...
# 25%                 3.000000  ...
# 50%                19.000000  ...
# 75%                37.000000  ...
# max                44.000000  ...
#
#        Curricular_units_1st_sem_without_evaluations  \
# count                                   4424.000000
# mean                                       0.137658
# std                                        0.690880
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       12.000000
#
#        Curricular_units_2nd_sem_credited  Curricular_units_2nd_sem_enrolled  \
# count                        4424.000000                        4424.000000
# mean                            0.541817                           6.232143
# std                             1.918546                           2.195951
# min                             0.000000                           0.000000
# 25%                             0.000000                           5.000000
# 50%                             0.000000                           6.000000
# 75%                             0.000000                           7.000000
# max                            19.000000                          23.000000
#
#        Curricular_units_2nd_sem_evaluations  \
# count                           4424.000000
# mean                               8.063291
# std                                3.947951
# min                                0.000000
# 25%                                6.000000
# 50%                                8.000000
# 75%                               10.000000
# max                               33.000000
#
#        Curricular_units_2nd_sem_approved  Curricular_units_2nd_sem_grade  \
# count                        4424.000000                     4424.000000
# mean                            4.435805                       10.230206
# std                             3.014764                        5.210808
# min                             0.000000                        0.000000
# 25%                             2.000000                       10.750000
# 50%                             5.000000                       12.200000
# 75%                             6.000000                       13.333333
# max                            20.000000                       18.571429
#
#        Curricular_units_2nd_sem_without_evaluations  Unemployment_rate  \
# count                                   4424.000000        4424.000000
# mean                                       0.150316          11.566139
# std                                        0.753774           2.663850
# min                                        0.000000           7.600000
# 25%                                        0.000000           9.400000
# 50%                                        0.000000          11.100000
# 75%                                        0.000000          13.900000
# max                                       12.000000          16.200000
#
#        Inflation_rate          GDP
# count     4424.000000  4424.000000
# mean         1.228029     0.001969
# std          1.382711     2.269935
# min         -0.800000    -4.060000
# 25%          0.300000    -1.700000
# 50%          1.400000     0.320000
# 75%          2.600000     1.790000
# max          3.700000     3.510000
#
# [8 rows x 36 columns]

# %% [markdown]
# ### Distribusi Target (Status Mahasiswa)
#
# Target variabel adalah `Status` dengan 3 kategori asli:
# - **Graduate**: Mahasiswa yang telah lulus
# - **Dropout**: Mahasiswa yang keluar sebelum menyelesaikan studi
# - **Enrolled**: Mahasiswa yang masih terdaftar (status sementara)
#
# **Catatan Penting**: Untuk training model, hanya digunakan data **Dropout** dan **Graduate** karena keduanya merupakan outcome akhir yang sudah pasti. Data **Enrolled** akan digunakan pada tahap inferensi untuk memprediksi kemungkinan status akhir di masa depan.

# %%
status_counts = df['Status'].value_counts()
print("Distribusi Status Mahasiswa (Seluruh Data):")
print(status_counts)
print(f"\nPersentase:")
print((status_counts / len(df) * 100).round(2))

plt.figure(figsize=(10, 6))
colors = {'Graduate': '#2ecc71', 'Dropout': '#e74c3c', 'Enrolled': '#3498db'}
status_counts.plot(kind='bar', color=[colors[x] for x in status_counts.index])
plt.title('Distribusi Status Mahasiswa (Seluruh Data)', fontsize=14, fontweight='bold')
plt.xlabel('Status')
plt.ylabel('Jumlah')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print(f"\nInsight:")
print(f"- Total data: {len(df)} mahasiswa")
print(f"- Dropout: {status_counts.get('Dropout', 0)} ({status_counts.get('Dropout', 0)/len(df)*100:.1f}%)")
print(f"- Graduate: {status_counts.get('Graduate', 0)} ({status_counts.get('Graduate', 0)/len(df)*100:.1f}%)")
print(f"- Enrolled: {status_counts.get('Enrolled', 0)} ({status_counts.get('Enrolled', 0)/len(df)*100:.1f}%)")
print(f"\nData Enrolled akan digunakan untuk inferensi, bukan training.")
# Out:
# Distribusi Status Mahasiswa (Seluruh Data):
# Status
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64
#
# Persentase:
# Status
# Graduate    49.93
# Dropout     32.12
# Enrolled    17.95
# Name: count, dtype: float64
# Insight:
# - Total data: 4424 mahasiswa
# - Dropout: 1421 (32.1%)
# - Graduate: 2209 (49.9%)
# - Enrolled: 794 (17.9%)
#
# Data Enrolled akan digunakan untuk inferensi, bukan training.

# %% [markdown]
# ### Filtering Data untuk Training
#
# Data yang digunakan untuk training hanya mencakup mahasiswa dengan status **Dropout** dan **Graduate**. Data Enrolled disimpan terpisah untuk inferensi.

# %%
# Filter data: hanya Dropout dan Graduate untuk training
df_train = df[df['Status'].isin(['Dropout', 'Graduate'])].copy()

# Simpan data Enrolled untuk inferensi (opsional)
df_enrolled = df[df['Status'] == 'Enrolled'].copy()

print(f"Data untuk training: {len(df_train)} mahasiswa")
print(f"  - Dropout: {len(df_train[df_train['Status'] == 'Dropout'])}")
print(f"  - Graduate: {len(df_train[df_train['Status'] == 'Graduate'])}")
print(f"\nData Enrolled (untuk inferensi): {len(df_enrolled)} mahasiswa")

# Visualisasi distribusi data training
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Sebelum filter
status_counts.plot(kind='bar', ax=axes[0], color=[colors[x] for x in status_counts.index])
axes[0].set_title('Seluruh Data (4424)', fontweight='bold')
axes[0].set_ylabel('Jumlah')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=0)

# Sesudah filter
train_counts = df_train['Status'].value_counts()
train_counts.plot(kind='bar', ax=axes[1], color=['#e74c3c', '#2ecc71'])
axes[1].set_title(f'Data Training ({len(df_train)})', fontweight='bold')
axes[1].set_ylabel('Jumlah')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=0)

plt.tight_layout()
plt.show()
# Out:
# Data untuk training: 3630 mahasiswa
#   - Dropout: 1421
#   - Graduate: 2209
#
# Data Enrolled (untuk inferensi): 794 mahasiswa

# %% [markdown]
# ---
# ## Exploratory Data Analysis (EDA)
#
# ### Faktor Finansial
# Analisis pengaruh status debitur, keterlambatan pembayaran, dan beasiswa terhadap dropout.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

pd.crosstab(df['Debtor'], df['Status'], normalize='index').plot(kind='bar', ax=axes[0])
axes[0].set_title('Status Debitur vs Status', fontweight='bold')
axes[0].set_xlabel('Debtor (0=No, 1=Yes)')
axes[0].set_ylabel('Proporsi')
axes[0].legend(title='Status')

pd.crosstab(df['Tuition_fees_up_to_date'], df['Status'], normalize='index').plot(kind='bar', ax=axes[1])
axes[1].set_title('Biaya Kuliah Tertib vs Status', fontweight='bold')
axes[1].set_xlabel('Tuition Fees (0=Tidak, 1=Tertib)')
axes[1].set_ylabel('Proporsi')
axes[1].legend(title='Status')

pd.crosstab(df['Scholarship_holder'], df['Status'], normalize='index').plot(kind='bar', ax=axes[2])
axes[2].set_title('Penerima Beasiswa vs Status', fontweight='bold')
axes[2].set_xlabel('Scholarship (0=No, 1=Yes)')
axes[2].set_ylabel('Proporsi')
axes[2].legend(title='Status')

plt.tight_layout()
plt.show()

print("\nInsight:")
print("- Debitur memiliki dropout rate lebih tinggi")
print("- Biaya tidak tertib meningkatkan risiko dropout")
print("- Penerima beasiswa memiliki dropout rate lebih rendah")
# Out:
# Insight:
# - Debitur memiliki dropout rate lebih tinggi
# - Biaya tidak tertib meningkatkan risiko dropout
# - Penerima beasiswa memiliki dropout rate lebih rendah

# %% [markdown]
# ### Faktor Akademik
# Analisis performa akademik berdasarkan status mahasiswa.

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

df.boxplot(column='Admission_grade', by='Status', ax=axes[0, 0])
axes[0, 0].set_title('Admission Grade vs Status', fontweight='bold')
axes[0, 0].set_xlabel('Status')
axes[0, 0].set_ylabel('Admission Grade')

df.boxplot(column='Curricular_units_1st_sem_approved', by='Status', ax=axes[0, 1])
axes[0, 1].set_title('Unit Lulus Semester 1 vs Status', fontweight='bold')
axes[0, 1].set_xlabel('Status')
axes[0, 1].set_ylabel('Unit Lulus Sem 1')

df.boxplot(column='Curricular_units_2nd_sem_approved', by='Status', ax=axes[1, 0])
axes[1, 0].set_title('Unit Lulus Semester 2 vs Status', fontweight='bold')
axes[1, 0].set_xlabel('Status')
axes[1, 0].set_ylabel('Unit Lulus Sem 2')

df.boxplot(column='Curricular_units_2nd_sem_grade', by='Status', ax=axes[1, 1])
axes[1, 1].set_title('Rata-rata Nilai Semester 2 vs Status', fontweight='bold')
axes[1, 1].set_xlabel('Status')
axes[1, 1].set_ylabel('Nilai Sem 2')

plt.tight_layout()
plt.show()

print("\nInsight:")
print("- Mahasiswa dropout memiliki nilai masuk lebih rendah")
print("- Jumlah unit lulus semester 1 & 2 lebih sedikit pada dropout")
print("- Nilai semester 2 juga lebih rendah pada dropout")
# Out:
# Insight:
# - Mahasiswa dropout memiliki nilai masuk lebih rendah
# - Jumlah unit lulus semester 1 & 2 lebih sedikit pada dropout
# - Nilai semester 2 juga lebih rendah pada dropout

# %% [markdown]
# ### Heatmap Korelasi
# Melihat hubungan antar fitur numerik.

# %%
key_features = [
    'Admission_grade', 'Previous_qualification_grade',
    'Curricular_units_1st_sem_enrolled', 'Curricular_units_1st_sem_approved',
    'Curricular_units_1st_sem_grade', 'Curricular_units_2nd_sem_enrolled',
    'Curricular_units_2nd_sem_approved', 'Curricular_units_2nd_sem_grade',
    'Unemployment_rate', 'Inflation_rate', 'GDP'
]

plt.figure(figsize=(12, 10))
corr_matrix = df[key_features].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title('Heatmap Korelasi Fitur', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Import Data ke PostgreSQL
#
# Import data ke database PostgreSQL untuk dashboard Metabase.
#
# **Prasyarat**: Docker PostgreSQL sudah jalan (`docker-compose up -d`)

# %%
try:
    engine = create_engine('postgresql://postgres:mysecretpassword@localhost:5432/student_dropout')
    df.to_sql('data', engine, if_exists='replace', index=False)
    
    with engine.connect() as conn:
        result = conn.execute(text('SELECT COUNT(*) FROM "data"'))
        count = result.scalar()
    
    print(f"✅ Berhasil import {count} baris ke PostgreSQL!")
    print(f"   Tabel: 'data'")
    print(f"   Database: student_dropout")
    print("\nBuka Metabase: http://localhost:3000")
    print("Login: root@mail.com / root123")
except Exception as e:
    print(f"⚠️ Gagal import ke database: {e}")
    print("Pastikan Docker PostgreSQL sudah jalan: docker-compose up -d")
# Out:
# ✅ Berhasil import 4424 baris ke PostgreSQL!
#    Tabel: 'data'
#    Database: student_dropout
#
# Buka Metabase: http://localhost:3000
# Login: root@mail.com / root123

# %% [markdown]
# ---
# ## Data Preparation / Preprocessing

# %% [markdown]
# ### Seleksi Fitur
#
# Fitur yang digunakan untuk modeling:

# %%
features = [
    # Demografi
    'Marital_status', 'Gender', 'Age_at_enrollment', 'International',
    # Akademik
    'Admission_grade', 'Previous_qualification_grade',
    # Kurikulum Semester 1
    'Curricular_units_1st_sem_enrolled', 'Curricular_units_1st_sem_approved',
    'Curricular_units_1st_sem_grade',
    # Kurikulum Semester 2
    'Curricular_units_2nd_sem_enrolled', 'Curricular_units_2nd_sem_approved',
    'Curricular_units_2nd_sem_grade',
    # Finansial
    'Debtor', 'Tuition_fees_up_to_date', 'Scholarship_holder',
    # Ekonomi
    'Unemployment_rate', 'Inflation_rate', 'GDP'
]

target = 'Status'

# Gunakan df_train (hanya Dropout dan Graduate)
X = df_train[features]
y = df_train[target]

print(f"Jumlah fitur: {len(features)}")
print(f"Jumlah data training: {len(X)}")
print(f"\nFitur yang dipilih:")
for i, f in enumerate(features, 1):
    print(f"  {i}. {f}")
# Out:
# Jumlah fitur: 18
# Jumlah data training: 3630
#
# Fitur yang dipilih:
#   1. Marital_status
#   2. Gender
#   3. Age_at_enrollment
#   4. International
#   5. Admission_grade
#   6. Previous_qualification_grade
#   7. Curricular_units_1st_sem_enrolled
#   8. Curricular_units_1st_sem_approved
#   9. Curricular_units_1st_sem_grade
#   10. Curricular_units_2nd_sem_enrolled
#   11. Curricular_units_2nd_sem_approved
#   12. Curricular_units_2nd_sem_grade
#   13. Debtor
#   14. Tuition_fees_up_to_date
#   15. Scholarship_holder
#   16. Unemployment_rate
#   17. Inflation_rate
#   18. GDP

# %% [markdown]
# ### Encoding Target Variable

# %%
label_encoder_target = LabelEncoder()
y_encoded = label_encoder_target.fit_transform(y)

print("Label mapping (Binary Classification):")
for i, label in enumerate(label_encoder_target.classes_):
    print(f"  {label} -> {i}")

print(f"\nJumlah kelas: {len(label_encoder_target.classes_)}")
print(f"Distribusi: Dropout={sum(y == 'Dropout')}, Graduate={sum(y == 'Graduate')}")
# Out:
# Label mapping (Binary Classification):
#   Dropout -> 0
#   Graduate -> 1
#
# Jumlah kelas: 2
# Distribusi: Dropout=1421, Graduate=2209

# %% [markdown]
# ### Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"Training set: {X_train.shape[0]} samples")
print(f"Testing set:  {X_test.shape[0]} samples")
print(f"Split ratio:  80% train, 20% test")
print(f"\nDistribusi target training:")
print(f"  Dropout:  {sum(y_train == 0)}")
print(f"  Graduate: {sum(y_train == 1)}")
# Out:
# Training set: 2904 samples
# Testing set:  726 samples
# Split ratio:  80% train, 20% test
#
# Distribusi target training:
#   Dropout:  1137
#   Graduate: 1767

# %% [markdown]
# ### Feature Scaling

# %%
scaler = StandardScaler()

numerical_cols = [
    'Age_at_enrollment', 'Admission_grade', 'Previous_qualification_grade',
    'Curricular_units_1st_sem_enrolled', 'Curricular_units_1st_sem_approved',
    'Curricular_units_1st_sem_grade', 'Curricular_units_2nd_sem_enrolled',
    'Curricular_units_2nd_sem_approved', 'Curricular_units_2nd_sem_grade',
    'Unemployment_rate', 'Inflation_rate', 'GDP'
]

X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

print(f"✅ Feature scaling selesai ({len(numerical_cols)} fitur numerik)")
# Out:
# ✅ Feature scaling selesai (12 fitur numerik)

# %% [markdown]
# ---
# ## Modeling
#
# ### Solusi Machine Learning yang Digunakan
#
# 1. **Logistic Regression** (Baseline)
#    - Interpretasi mudah, probabilitas dropout
#    - Cocok untuk binary classification
#
# 2. **Random Forest** (Utama)
#    - Akurasi lebih tinggi
#    - Feature importance
#    - Robust terhadap outlier
#
# **Catatan**: Karena hanya menggunakan 2 kelas (Dropout vs Graduate), model akan lebih fokus dan akurat dalam membedakan kedua outcome akhir yang sudah pasti.

# %%
# MODEL 1: LOGISTIC REGRESSION (Binary Classification)
print("=" * 60)
print("MODEL 1: LOGISTIC REGRESSION")
print("Klasifikasi Binary: Dropout vs Graduate")
print("=" * 60)

lr_model = LogisticRegression(
    max_iter=2000,
    random_state=42,
    solver='lbfgs'
)
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)
y_prob_lr = lr_model.predict_proba(X_test)

accuracy_lr = accuracy_score(y_test, y_pred_lr)
print(f"\nAccuracy: {accuracy_lr:.4f}")
print(f"\nClassification Report:")
print(classification_report(y_test, y_pred_lr, target_names=label_encoder_target.classes_))
# Out:
# ============================================================
# MODEL 1: LOGISTIC REGRESSION
# Klasifikasi Binary: Dropout vs Graduate
# ============================================================
#
# Accuracy: 0.9201
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.96      0.83      0.89       284
#     Graduate       0.90      0.98      0.94       442
#
#     accuracy                           0.92       726
#    macro avg       0.93      0.90      0.91       726
# weighted avg       0.92      0.92      0.92       726

# %%
# MODEL 2: RANDOM FOREST (Binary Classification)
print("=" * 60)
print("MODEL 2: RANDOM FOREST")
print("Klasifikasi Binary: Dropout vs Graduate")
print("=" * 60)

rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=15,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)

accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"\nAccuracy: {accuracy_rf:.4f}")
print(f"\nClassification Report:")
print(classification_report(y_test, y_pred_rf, target_names=label_encoder_target.classes_))
# Out:
# ============================================================
# MODEL 2: RANDOM FOREST
# Klasifikasi Binary: Dropout vs Graduate
# ============================================================
#
# Accuracy: 0.9077
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.95      0.81      0.87       284
#     Graduate       0.89      0.97      0.93       442
#
#     accuracy                           0.91       726
#    macro avg       0.92      0.89      0.90       726
# weighted avg       0.91      0.91      0.91       726

# %% [markdown]
# ---
# ## Evaluation

# %% [markdown]
# ### Perbandingan Model

# %%
print("=" * 60)
print("PERBANDINGAN MODEL (Binary: Dropout vs Graduate)")
print("=" * 60)

print("\n+---------------------+----------------+----------------+")
print("| Metrik              | Logistic Reg   | Random Forest  |")
print("+---------------------+----------------+----------------+")
print(f"| Accuracy            | {accuracy_lr:>14.4f} | {accuracy_rf:>14.4f} |")
print("+---------------------+----------------+----------------+")

if accuracy_rf > accuracy_lr:
    print("\n=> Random Forest lebih baik!")
    best_model = rf_model
    best_model_name = "Random Forest"
else:
    print("\n=> Logistic Regression lebih baik!")
    best_model = lr_model
    best_model_name = "Logistic Regression"
# Out:
# ============================================================
# PERBANDINGAN MODEL (Binary: Dropout vs Graduate)
# ============================================================
#
# +---------------------+----------------+----------------+
# | Metrik              | Logistic Reg   | Random Forest  |
# +---------------------+----------------+----------------+
# | Accuracy            |         0.9201 |         0.9077 |
# +---------------------+----------------+----------------+
#
# => Logistic Regression lebih baik!

# %% [markdown]
# ### Confusion Matrix

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

cm_lr = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=label_encoder_target.classes_,
            yticklabels=label_encoder_target.classes_)
axes[0].set_title(f'Logistic Regression\nAccuracy: {accuracy_lr:.4f}', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Greens', ax=axes[1],
            xticklabels=label_encoder_target.classes_,
            yticklabels=label_encoder_target.classes_)
axes[1].set_title(f'Random Forest\nAccuracy: {accuracy_rf:.4f}', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Importance
#
# Fitur yang paling mempengaruhi prediksi dropout:

# %%
feature_importance = pd.DataFrame({
    'Feature': features,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Top 10 Fitur Paling Penting:")
for idx, row in feature_importance.head(10).iterrows():
    bar = "█" * int(row['Importance'] * 50)
    print(f"  {row['Feature']:40s}: {row['Importance']:.4f} {bar}")

plt.figure(figsize=(10, 8))
feature_importance.head(15).plot(kind='barh', x='Feature', y='Importance', legend=False, color='#3498db')
plt.title('Top 15 Feature Importance', fontsize=14, fontweight='bold')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Top 10 Fitur Paling Penting:
#   Curricular_units_2nd_sem_approved       : 0.2975 ██████████████
#   Curricular_units_1st_sem_approved       : 0.1425 ███████
#   Curricular_units_2nd_sem_grade          : 0.1363 ██████
#   Curricular_units_1st_sem_grade          : 0.0861 ████
#   Tuition_fees_up_to_date                 : 0.0791 ███
#   Age_at_enrollment                       : 0.0400 █
#   Admission_grade                         : 0.0382 █
#   Curricular_units_1st_sem_enrolled       : 0.0335 █
#   Previous_qualification_grade            : 0.0306 █
#   Curricular_units_2nd_sem_enrolled       : 0.0280 █

# %% [markdown]
# samples = X_test.iloc[:5]
# actual = label_encoder_target.inverse_transform(y_test[:5])
#
# pred_lr = label_encoder_target.inverse_transform(lr_model.predict(samples))
# pred_rf = label_encoder_target.inverse_transform(rf_model.predict(samples))
#
# print("+----+------------+------------+------------+")
# print("| No | Actual     | LinearReg  | RandomForest|")
# print("+----+------------+------------+------------+")
# for i in range(5):
#     print(f"| {i+1:>2} | {actual[i]:>10} | {pred_lr[i]:>10} | {pred_rf[i]:>10} |")
# print("+----+------------+------------+------------+")

# %%
sample_indices = y_test[:5]
samples = X_test.iloc[:5]
actual = label_encoder_target.inverse_transform(y_test[:5])

pred_lr = label_encoder_target.inverse_transform(lr_model.predict(samples))
pred_rf = label_encoder_target.inverse_transform(rf_model.predict(samples))

print("+----+------------+------------+------------+")
print("| No | Actual     | LinearReg  | RandomForest|")
print("+----+------------+------------+------------+")
for i in range(5):
    print(f"| {i+1:>2} | {actual[i]:>10} | {pred_lr[i]:>10} | {pred_rf[i]:>10} |")
print("+----+------------+------------+------------+")
# Out:
# +----+------------+------------+------------+
# | No | Actual     | LinearReg  | RandomForest|
# +----+------------+------------+------------+
# |  1 |    Dropout |    Dropout |   Graduate |
# |  2 |   Graduate |   Graduate |   Graduate |
# |  3 |   Graduate |   Graduate |   Graduate |
# |  4 |   Graduate |   Graduate |   Graduate |
# |  5 |   Graduate |   Graduate |   Graduate |
# +----+------------+------------+------------+

# %% [markdown]
# ---
# ## Simpan Model
#
# Model binary classification (Dropout vs Graduate) disimpan untuk digunakan di Streamlit app.

# %%
import os
os.makedirs('model', exist_ok=True)

joblib.dump(best_model, 'model/model_dropout.pkl')
print(f"✅ Model tersimpan: model/model_dropout.pkl")

joblib.dump(scaler, 'model/scaler.pkl')
print(f"✅ Scaler tersimpan: model/scaler.pkl")

joblib.dump(label_encoder_target, 'model/label_encoders.pkl')
print(f"✅ Label encoder tersimpan: model/label_encoders.pkl")

print("\n🚀 Model berhasil disimpan!")
print("Jalankan Streamlit: streamlit run app.py")
# Out:
# ✅ Model tersimpan: model/model_dropout.pkl
# ✅ Scaler tersimpan: model/scaler.pkl
# ✅ Label encoder tersimpan: model/label_encoders.pkl
#
# 🚀 Model berhasil disimpan!
# Jalankan Streamlit: streamlit run app.py

# %% [markdown]
# ---
# ## Dashboard Metabase
#
# Dashboard dibuat di Metabase untuk monitoring. Query ada di `queries/dashboard_queries.sql`.
#
# ### Yang Ditampilkan di Dashboard
# | Query | Fungsi |
# |-------|--------|
# | Query 1 | Distribusi status mahasiswa |
# | Query 2 | Faktor finansial (debitur, pembayaran, beasiswa) |
# | Query 3 | Performa akademik per status |
# | Query 4 | Dropout per program studi |
# | Query 5 | Distribusi per usia |
# | Query 6 | Perbandingan gender |
# | Query 7 | Pengaruh beasiswa |
# | Query 8 | Pengaruh debitur |
# | Query 9 | Analisis unit gagal |
# | Query 10 | Identifikasi risiko tinggi |
# | Query 11 | Komparasi dropout vs graduate |
# | Query 12 | Pengaruh kondisi ekonomi |
#
# ### Akses
# - URL: http://localhost:3000
# - Login: root@mail.com / root123

# %% [markdown]
# ---
# ## Prototype Streamlit
#
# Streamlit app menggunakan model binary classification (Dropout vs Graduate) untuk prediksi.

# %% [markdown]
# ---
# ## Inferensi pada Data Enrolled (Opsional)
#
# Bagian ini menggunakan model yang sudah dilatih untuk memprediksi kemungkinan status akhir mahasiswa yang masih **Enrolled**. Ini membantu mengidentifikasi mahasiswa berisiko dropout sebelum mereka benar-benar keluar.

# %%
# Inferensi pada data Enrolled
print("=" * 60)
print("INFERENSI PADA DATA ENROLLED")
print("=" * 60)

if len(df_enrolled) > 0:
    X_enrolled = df_enrolled[features]
    X_enrolled_scaled = X_enrolled.copy()
    X_enrolled_scaled[numerical_cols] = scaler.transform(X_enrolled[numerical_cols])
    enrolled_pred = best_model.predict(X_enrolled_scaled)
    enrolled_prob = best_model.predict_proba(X_enrolled_scaled)
    enrolled_pred_labels = label_encoder_target.inverse_transform(enrolled_pred)
    dropout_count = sum(enrolled_pred_labels == "Dropout")
    graduate_count = sum(enrolled_pred_labels == "Graduate")
    print(f"\nTotal Enrolled: {len(df_enrolled)}")
    print(f"Prediksi Dropout: {dropout_count} ({dropout_count/len(df_enrolled)*100:.1f}%)")
    print(f"Prediksi Graduate: {graduate_count} ({graduate_count/len(df_enrolled)*100:.1f}%)")
    pred_counts = pd.Series(enrolled_pred_labels).value_counts()
    pred_counts.plot(kind="bar", color=["#e74c3c","#2ecc71"])
    plt.title("Prediksi Status Akhir Mahasiswa Enrolled")
    plt.ylabel("Jumlah")
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()
else:
    print("Tidak ada data Enrolled.")
# Out:
# ============================================================
# INFERENSI PADA DATA ENROLLED
# ============================================================
#
# Total Enrolled: 794
# Prediksi Dropout: 332 (41.8%)
# Prediksi Graduate: 462 (58.2%)

# %% [markdown]
# ---
# ## Kesimpulan
#
# ### Pendekatan
# - Model dilatih menggunakan **binary classification** (Dropout vs Graduate)
# - Data Enrolled (status sementara) **tidak digunakan untuk training** karena bukan outcome akhir
# - Data Enrolled dapat digunakan untuk **inferensi/prediksi** kemungkinan status akhir
#
# ### Hasil Analisis
#
# Faktor utama yang mempengaruhi dropout mahasiswa:
#
# 1. **Finansial**: Status debitur dan keterlambatan biaya kuliah adalah prediktor terkuat
# 2. **Akademik**: Jumlah satuan kredit yang tidak lulus di semester 1 dan 2
# 3. **Beasiswa**: Mahasiswa dengan beasiswa memiliki risiko dropout lebih rendah
# 4. **Nilai Masuk**: Admission grade yang rendah berkorelasi dengan dropout
#
# ### Performa Model
#
# | Metrik | Logistic Regression | Random Forest |
# |--------|---------------------|---------------|
# | Accuracy | (dari output cell di atas) | (dari output cell di atas) |
#
# **Best Model**: (dari output cell di atas)
#
# ### Rekomendasi
# 1. Gunakan model untuk identifikasi dini mahasiswa berisiko dropout
# 2. Fokuskan intervensi pada faktor finansial dan akademik
# 3. Monitoring berkala menggunakan dashboard Metabase
# 4. Gunakan data Enrolled untuk prediksi prospektif
